# %%
import pandas as pd

df = pd.read_csv(r'data/raw/online_sales_dataset.csv')

# %%
df
# Out:
#        InvoiceNo StockCode   Description  Quantity       InvoiceDate  \
# 0         221958  SKU_1964     White Mug        38  2020-01-01 00:00
# 1         771155  SKU_1241     White Mug        18  2020-01-01 01:00
# 2         231932  SKU_1501    Headphones        49  2020-01-01 02:00
# 3         465838  SKU_1760     Desk Lamp        14  2020-01-01 03:00
# 4         359178  SKU_1386     USB Cable       -30  2020-01-01 04:00
# ...          ...       ...           ...       ...               ...
# 49777     354083  SKU_1562      Blue Pen        25  2025-09-05 01:00
# 49778     296698  SKU_1930     USB Cable         7  2025-09-05 02:00
# 49779     177622  SKU_1766  Office Chair        43  2025-09-05 03:00
# 49780     701213  SKU_1602      Notebook        48  2025-09-05 04:00
# 49781     772215  SKU_1832     White Mug        30  2025-09-05 05:00
#
#        UnitPrice  CustomerID         Country  Discount  PaymentMethod  \
# ...

# %%
df.dtypes
# Out:
# InvoiceNo              int64
# StockCode             object
# Description           object
# Quantity               int64
# InvoiceDate           object
# UnitPrice            float64
# CustomerID           float64
# Country               object
# Discount             float64
# PaymentMethod         object
# ShippingCost         float64
# Category              object
# SalesChannel          object
# ReturnStatus          object
# ShipmentProvider      object
# WarehouseLocation     object
# OrderPriority         object
# dtype: object

# %%
# Check for CustomerID values with decimals not equal to .0
# Drop NaN values before checking for decimals in CustomerID
df_no_nan = df.dropna(subset=['CustomerID'])
df_no_nan[df_no_nan['CustomerID'] % 1 != 0]
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country, Discount, PaymentMethod, ShippingCost, Category, SalesChannel, ReturnStatus, ShipmentProvider, WarehouseLocation, OrderPriority]
# Index: []

# %%
# Count duplicates in each feature (column)
for col in df_no_nan.columns:
    dup_count = df_no_nan[col].duplicated().sum()
    print(f"{col}: {dup_count} duplicates")
# Out:
# InvoiceNo: 1035 duplicates
# StockCode: 43804 duplicates
# Description: 44793 duplicates
# Quantity: 44755 duplicates
# InvoiceDate: 0 duplicates
# UnitPrice: 35030 duplicates
# CustomerID: 9415 duplicates
# Country: 44792 duplicates
# Discount: 44753 duplicates
# PaymentMethod: 44801 duplicates
# ShippingCost: 42303 duplicates
# Category: 44799 duplicates
# SalesChannel: 44802 duplicates
# ReturnStatus: 44802 duplicates
# ShipmentProvider: 44800 duplicates
# WarehouseLocation: 44799 duplicates
# OrderPriority: 44801 duplicates
